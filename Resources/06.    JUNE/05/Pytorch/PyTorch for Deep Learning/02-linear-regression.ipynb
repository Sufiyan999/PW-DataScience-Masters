# %%
# !nvidia-smi
# Out:
# Fri Dec 24 09:37:18 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    27W / 149W |      3MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import torch

# %%
#making training data 
# Input (temp, rainfall, humidity)
inputs = np.array([[73, 67, 43], 
                   [91, 88, 64], 
                   [87, 134, 58], 
                   [102, 43, 37], 
                   [69, 96, 70]], dtype='float32')

# %%
# Targets (apples, oranges)
target = np.array([[56, 70], 
                    [81, 101], 
                    [119, 133], 
                    [22, 37], 
                    [103, 119]], dtype='float32')

# %%
#Convert input and target to tensors
inputs = torch.from_numpy(inputs)
target = torch.from_numpy(target)

print(inputs,"\n")
print(target)
# Out:
# tensor([[ 73.,  67.,  43.],
#         [ 91.,  88.,  64.],
#         [ 87., 134.,  58.],
#         [102.,  43.,  37.],
#         [ 69.,  96.,  70.]])
#
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %%
# weights and biases
w = torch.randn(2,3 , requires_grad=True)
b = torch.randn(2, requires_grad=True)

print(w)
print(b)
# Out:
# tensor([[-0.7145,  1.2718, -0.1902],
#         [-0.7467,  1.0642,  0.6049]], requires_grad=True)
# tensor([-0.7670,  0.0596], requires_grad=True)

# %%
#define the model

def model(x):
  return x @ w.t() + b

# %%
# prediction
preds = model(inputs)
print(preds)
# Out:
# tensor([[ 24.1113,  42.8640],
#         [ 33.9653,  64.4753],
#         [ 96.4693, 112.7846],
#         [-25.9916,  -7.9600],
#         [ 58.7174,  93.0456]], grad_fn=<AddBackward0>)

# %%
#actual
print(target)
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %%
# loss function MSE
def MSE(actual, target):
  diff = actual - target
  return torch.sum(diff * diff) / diff.numel()

# %%
# error
loss = MSE(target, preds)
print(loss)
# Out:
# tensor(1317.5035, grad_fn=<DivBackward0>)

# %%
# compute gradients
loss.backward()

# %%
print(w, "\n")
print(w.grad)
# Out:
# tensor([[-0.7145,  1.2718, -0.1902],
#         [-0.7467,  1.0642,  0.6049]], requires_grad=True)
#
# tensor([[-3303.7683, -3121.8945, -2112.7368],
#         [-2688.0376, -2433.2100, -1631.4502]])

# %%
print(b, "\n")
print(b.grad)
# Out:
# tensor([-0.7670,  0.0596], requires_grad=True)
#
# tensor([-38.7457, -30.9581])

# %%
#reset grad
w.grad.zero_()
b.grad.zero_()

print(w.grad)
print(b.grad)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# tensor([0., 0.])

# %%
# adjust params

preds = model(inputs)
print(preds)
# Out:
# tensor([[ 24.1113,  42.8640],
#         [ 33.9653,  64.4753],
#         [ 96.4693, 112.7846],
#         [-25.9916,  -7.9600],
#         [ 58.7174,  93.0456]], grad_fn=<AddBackward0>)

# %%
# loss
loss = MSE(target, preds)
print(loss)
# Out:
# tensor(1317.5035, grad_fn=<DivBackward0>)

# %%
loss.backward()

print(w.grad, "\n")
print(b.grad)
# Out:
# tensor([[-3303.7683, -3121.8945, -2112.7368],
#         [-2688.0376, -2433.2100, -1631.4502]])
#
# tensor([-38.7457, -30.9581])

# %%
  # adjust weight & reset grad
with torch.no_grad():
    w -= w.grad * 1e-5
    b -= b.grad * 1e-5
    w.grad.zero_()
    b.grad.zero_()

# %%
print(w)
print(b)
# Out:
# tensor([[-0.6814,  1.3031, -0.1691],
#         [-0.7198,  1.0885,  0.6213]], requires_grad=True)
# tensor([-0.7666,  0.0599], requires_grad=True)

# %%
# calculate again
preds = model(inputs)
loss = MSE(target, preds)
print(loss)
# Out:
# tensor(944.6516, grad_fn=<DivBackward0>)

# %%
# Training for multiple epochs
for i in range(400):
  preds = model(inputs)
  loss = MSE(target, preds)
  loss.backward()

  with torch.no_grad():
     w -= w.grad * 1e-5 # learning rate
     b -= b.grad * 1e-5
     w.grad.zero_()
     b.grad.zero_()
  print(f"Epochs({i}/{100}) & Loss {loss}")
# Out:
# Epochs(0/100) & Loss 944.6515502929688
# Epochs(1/100) & Loss 692.81640625
# Epochs(2/100) & Loss 522.5397338867188
# Epochs(3/100) & Loss 407.2310485839844
# Epochs(4/100) & Loss 328.97125244140625
# Epochs(5/100) & Loss 275.68511962890625
# Epochs(6/100) & Loss 239.23495483398438
# Epochs(7/100) & Loss 214.13687133789062
# Epochs(8/100) & Loss 196.69528198242188
# Epochs(9/100) & Loss 184.41964721679688
# Epochs(10/100) & Loss 175.63180541992188
# Epochs(11/100) & Loss 169.2005157470703
# Epochs(12/100) & Loss 164.36334228515625
# Epochs(13/100) & Loss 160.6066436767578
# Epochs(14/100) & Loss 157.58407592773438
# Epochs(15/100) & Loss 155.06198120117188
# Epochs(16/100) & Loss 152.8831329345703
# Epochs(17/100) & Loss 150.94161987304688
# Epochs(18/100) & Loss 149.1654510498047
# Epochs(19/100) & Loss 147.5065460205078
# Epochs(20/100) & Loss 145.9321746826172
# Epochs(21/100) & Loss 144.4202117919922
# Epochs(22/100) & Loss 142.95587158203125
# Epochs(23/100) & Loss 141.52902221679688
# Epochs(24/100) & Loss 140.13259887695312
# Epochs(25/100) & Loss 138.7620391845703
# Epochs(26/100) & Loss 137.4140167236328
# Epochs(27/100) & Loss 136.0863037109375
# Epochs(28/100) & Loss 134.77748107910156
# Epochs(29/100) & Loss 133.4860382080078
# Epochs(30/100) & Loss 132.21148681640625
# Epochs(31/100) & Loss 130.95309448242188
# Epochs(32/100) & Loss 129.71041870117188
# Epochs(33/100) & Loss 128.4830322265625
# Epochs(34/100) & Loss 127.27055358886719
# Epochs(35/100) & Loss 126.0730972290039
# Epochs(36/100) & Loss 124.88997650146484
# Epochs(37/100) & Loss 123.72108459472656
# Epochs(38/100) & Loss 122.56620788574219
# Epochs(39/100) & Loss 121.42533874511719
# Epochs(40/100) & Loss 120.29795837402344
# Epochs(41/100) & Loss 119.18426513671875
# Epochs(42/100) & Loss 118.08377838134766
# Epochs(43/100) & Loss 116.99653625488281
# Epochs(44/100) & Loss 115.92227935791016
# Epochs(45/100) & Loss 114.86076354980469
# Epochs(46/100) & Loss 113.8119125366211
# Epochs(47/100) & Loss 112.77571105957031
# Epochs(48/100) & Loss 111.75178527832031
# Epochs(49/100) & Loss 110.74012756347656
# Epochs(50/100) & Loss 109.7402572631836
# Epochs(51/100) & Loss 108.75254821777344
# Epochs(52/100) & Loss 107.77644348144531
# Epochs(53/100) & Loss 106.81196594238281
# Epochs(54/100) & Loss 105.85899353027344
# Epochs(55/100) & Loss 104.91739654541016
# Epochs(56/100) & Loss 103.9868392944336
# Epochs(57/100) & Loss 103.06730651855469
# Epochs(58/100) & Loss 102.1587142944336
# Epochs(59/100) & Loss 101.26081848144531
# Epochs(60/100) & Loss 100.37357330322266
# Epochs(61/100) & Loss 99.49687957763672
# Epochs(62/100) & Loss 98.63047790527344
# Epochs(63/100) & Loss 97.77420806884766
# Epochs(64/100) & Loss 96.92811584472656
# Epochs(65/100) & Loss 96.09197998046875
# Epochs(66/100) & Loss 95.26578521728516
# Epochs(67/100) & Loss 94.44920349121094
# Epochs(68/100) & Loss 93.64228820800781
# Epochs(69/100) & Loss 92.84483337402344
# Epochs(70/100) & Loss 92.05672454833984
# Epochs(71/100) & Loss 91.27787780761719
# Epochs(72/100) & Loss 90.50811004638672
# Epochs(73/100) & Loss 89.74748992919922
# Epochs(74/100) & Loss 88.99568176269531
# Epochs(75/100) & Loss 88.25267028808594
# Epochs(76/100) & Loss 87.51835632324219
# Epochs(77/100) & Loss 86.79255676269531
# Epochs(78/100) & Loss 86.07533264160156
# Epochs(79/100) & Loss 85.36639404296875
# Epochs(80/100) & Loss 84.66570281982422
# Epochs(81/100) & Loss 83.97322082519531
# Epochs(82/100) & Loss 83.28877258300781
# Epochs(83/100) & Loss 82.61228942871094
# Epochs(84/100) & Loss 81.94364929199219
# Epochs(85/100) & Loss 81.2828598022461
# Epochs(86/100) & Loss 80.62948608398438
# Epochs(87/100) & Loss 79.98393249511719
# Epochs(88/100) & Loss 79.34566497802734
# Epochs(89/100) & Loss 78.71488952636719
# Epochs(90/100) & Loss 78.09135437011719
# Epochs(91/100) & Loss 77.47505187988281
# Epochs(92/100) & Loss 76.8658218383789
# Epochs(93/100) & Loss 76.26359558105469
# Epochs(94/100) & Loss 75.6683578491211
# Epochs(95/100) & Loss 75.07981872558594
# Epochs(96/100) & Loss 74.49821472167969
# Epochs(97/100) & Loss 73.92313385009766
# Epochs(98/100) & Loss 73.35475158691406
# Epochs(99/100) & Loss 72.79281616210938
# Epochs(100/100) & Loss 72.23731994628906
# Epochs(101/100) & Loss 71.68819427490234
# Epochs(102/100) & Loss 71.14530944824219
# Epochs(103/100) & Loss 70.60863494873047
# Epochs(104/100) & Loss 70.07804870605469
# Epochs(105/100) & Loss 69.55359649658203
# Epochs(106/100) & Loss 69.03497314453125
# Epochs(107/100) & Loss 68.52236938476562
# Epochs(108/100) & Loss 68.01544189453125
# Epochs(109/100) & Loss 67.51435852050781
# Epochs(110/100) & Loss 67.01889038085938
# Epochs(111/100) & Loss 66.52903747558594
# Epochs(112/100) & Loss 66.04483032226562
# Epochs(113/100) & Loss 65.56593322753906
# Epochs(114/100) & Loss 65.09251403808594
# Epochs(115/100) & Loss 64.62437438964844
# Epochs(116/100) & Loss 64.1614990234375
# Epochs(117/100) & Loss 63.70384979248047
# Epochs(118/100) & Loss 63.25129318237305
# Epochs(119/100) & Loss 62.8038215637207
# Epochs(120/100) & Loss 62.361412048339844
# Epochs(121/100) & Loss 61.92384719848633
# Epochs(122/100) & Loss 61.491241455078125
# Epochs(123/100) & Loss 61.06352615356445
# Epochs(124/100) & Loss 60.64037322998047
# Epochs(125/100) & Loss 60.222137451171875
# Epochs(126/100) & Loss 59.8084602355957
# Epochs(127/100) & Loss 59.3992805480957
# Epochs(128/100) & Loss 58.994781494140625
# Epochs(129/100) & Loss 58.594696044921875
# Epochs(130/100) & Loss 58.199012756347656
# Epochs(131/100) & Loss 57.80780029296875
# Epochs(132/100) & Loss 57.4207878112793
# Epochs(133/100) & Loss 57.038002014160156
# Epochs(134/100) & Loss 56.65949249267578
# Epochs(135/100) & Loss 56.28508758544922
# Epochs(136/100) & Loss 55.91480255126953
# Epochs(137/100) & Loss 55.5486946105957
# Epochs(138/100) & Loss 55.186424255371094
# Epochs(139/100) & Loss 54.8281364440918
# Epochs(140/100) & Loss 54.473838806152344
# Epochs(141/100) & Loss 54.12328338623047
# Epochs(142/100) & Loss 53.776649475097656
# Epochs(143/100) & Loss 53.43364334106445
# Epochs(144/100) & Loss 53.094459533691406
# Epochs(145/100) & Loss 52.75897216796875
# Epochs(146/100) & Loss 52.42699432373047
# Epochs(147/100) & Loss 52.09868240356445
# Epochs(148/100) & Loss 51.77385711669922
# Epochs(149/100) & Loss 51.45258712768555
# Epochs(150/100) & Loss 51.13467025756836
# Epochs(151/100) & Loss 50.82019805908203
# Epochs(152/100) & Loss 50.50920104980469
# Epochs(153/100) & Loss 50.20131301879883
# Epochs(154/100) & Loss 49.896854400634766
# Epochs(155/100) & Loss 49.59558868408203
# Epochs(156/100) & Loss 49.29758071899414
# Epochs(157/100) & Loss 49.00269317626953
# Epochs(158/100) & Loss 48.71090316772461
# Epochs(159/100) & Loss 48.42224884033203
# Epochs(160/100) & Loss 48.136566162109375
# Epochs(161/100) & Loss 47.854000091552734
# Epochs(162/100) & Loss 47.574363708496094
# Epochs(163/100) & Loss 47.297637939453125
# Epochs(164/100) & Loss 47.02385711669922
# Epochs(165/100) & Loss 46.752960205078125
# Epochs(166/100) & Loss 46.48483657836914
# Epochs(167/100) & Loss 46.21954345703125
# Epochs(168/100) & Loss 45.957035064697266
# Epochs(169/100) & Loss 45.69717788696289
# Epochs(170/100) & Loss 45.4400520324707
# Epochs(171/100) & Loss 45.18555450439453
# Epochs(172/100) & Loss 44.933746337890625
# Epochs(173/100) & Loss 44.684486389160156
# Epochs(174/100) & Loss 44.43785858154297
# Epochs(175/100) & Loss 44.193748474121094
# Epochs(176/100) & Loss 43.952064514160156
# Epochs(177/100) & Loss 43.71290969848633
# Epochs(178/100) & Loss 43.476234436035156
# Epochs(179/100) & Loss 43.241966247558594
# Epochs(180/100) & Loss 43.01002883911133
# Epochs(181/100) & Loss 42.78038024902344
# Epochs(182/100) & Loss 42.55315399169922
# Epochs(183/100) & Loss 42.32823181152344
# Epochs(184/100) & Loss 42.1055793762207
# Epochs(185/100) & Loss 41.88515090942383
# Epochs(186/100) & Loss 41.66692352294922
# Epochs(187/100) & Loss 41.45093536376953
# Epochs(188/100) & Loss 41.23695755004883
# Epochs(189/100) & Loss 41.02531814575195
# Epochs(190/100) & Loss 40.81563186645508
# Epochs(191/100) & Loss 40.6081428527832
# Epochs(192/100) & Loss 40.402618408203125
# Epochs(193/100) & Loss 40.19921875
# Epochs(194/100) & Loss 39.99776077270508
# Epochs(195/100) & Loss 39.79823684692383
# Epochs(196/100) & Loss 39.60078048706055
# Epochs(197/100) & Loss 39.40522766113281
# Epochs(198/100) & Loss 39.211570739746094
# Epochs(199/100) & Loss 39.01979064941406
# Epochs(200/100) & Loss 38.829959869384766
# Epochs(201/100) & Loss 38.641849517822266
# Epochs(202/100) & Loss 38.45567321777344
# Epochs(203/100) & Loss 38.271240234375
# Epochs(204/100) & Loss 38.088600158691406
# Epochs(205/100) & Loss 37.907691955566406
# Epochs(206/100) & Loss 37.728580474853516
# Epochs(207/100) & Loss 37.55120086669922
# Epochs(208/100) & Loss 37.37542724609375
# Epochs(209/100) & Loss 37.20136260986328
# Epochs(210/100) & Loss 37.028953552246094
# Epochs(211/100) & Loss 36.85816955566406
# Epochs(212/100) & Loss 36.68901824951172
# Epochs(213/100) & Loss 36.521461486816406
# Epochs(214/100) & Loss 36.35541534423828
# Epochs(215/100) & Loss 36.1910285949707
# Epochs(216/100) & Loss 36.02809524536133
# Epochs(217/100) & Loss 35.866722106933594
# Epochs(218/100) & Loss 35.70686340332031
# Epochs(219/100) & Loss 35.54839324951172
# Epochs(220/100) & Loss 35.391563415527344
# Epochs(221/100) & Loss 35.23606491088867
# Epochs(222/100) & Loss 35.08198165893555
# Epochs(223/100) & Loss 34.92941665649414
# Epochs(224/100) & Loss 34.77821731567383
# Epochs(225/100) & Loss 34.62835693359375
# Epochs(226/100) & Loss 34.47976303100586
# Epochs(227/100) & Loss 34.3326530456543
# Epochs(228/100) & Loss 34.18682098388672
# Epochs(229/100) & Loss 34.04242706298828
# Epochs(230/100) & Loss 33.899192810058594
# Epochs(231/100) & Loss 33.75733184814453
# Epochs(232/100) & Loss 33.61670684814453
# Epochs(233/100) & Loss 33.477317810058594
# Epochs(234/100) & Loss 33.33915328979492
# Epochs(235/100) & Loss 33.20221710205078
# Epochs(236/100) & Loss 33.06650924682617
# Epochs(237/100) & Loss 32.93199920654297
# Epochs(238/100) & Loss 32.79865264892578
# Epochs(239/100) & Loss 32.66652297973633
# Epochs(240/100) & Loss 32.53549575805664
# Epochs(241/100) & Loss 32.40569305419922
# Epochs(242/100) & Loss 32.276939392089844
# Epochs(243/100) & Loss 32.14929962158203
# Epochs(244/100) & Loss 32.02275848388672
# Epochs(245/100) & Loss 31.897388458251953
# Epochs(246/100) & Loss 31.77301597595215
# Epochs(247/100) & Loss 31.649715423583984
# Epochs(248/100) & Loss 31.5274715423584
# Epochs(249/100) & Loss 31.4062557220459
# Epochs(250/100) & Loss 31.286121368408203
# Epochs(251/100) & Loss 31.166950225830078
# Epochs(252/100) & Loss 31.04876708984375
# Epochs(253/100) & Loss 30.931554794311523
# Epochs(254/100) & Loss 30.815414428710938
# Epochs(255/100) & Loss 30.700153350830078
# Epochs(256/100) & Loss 30.585880279541016
# Epochs(257/100) & Loss 30.472583770751953
# Epochs(258/100) & Loss 30.360183715820312
# Epochs(259/100) & Loss 30.24875259399414
# Epochs(260/100) & Loss 30.138172149658203
# Epochs(261/100) & Loss 30.028461456298828
# Epochs(262/100) & Loss 29.919750213623047
# Epochs(263/100) & Loss 29.811859130859375
# Epochs(264/100) & Loss 29.704849243164062
# Epochs(265/100) & Loss 29.598712921142578
# Epochs(266/100) & Loss 29.493362426757812
# Epochs(267/100) & Loss 29.388927459716797
# Epochs(268/100) & Loss 29.28530502319336
# Epochs(269/100) & Loss 29.1824893951416
# Epochs(270/100) & Loss 29.080524444580078
# Epochs(271/100) & Loss 28.97927474975586
# Epochs(272/100) & Loss 28.87888526916504
# Epochs(273/100) & Loss 28.779333114624023
# Epochs(274/100) & Loss 28.680429458618164
# Epochs(275/100) & Loss 28.582321166992188
# Epochs(276/100) & Loss 28.485065460205078
# Epochs(277/100) & Loss 28.388477325439453
# Epochs(278/100) & Loss 28.292593002319336
# Epochs(279/100) & Loss 28.197561264038086
# Epochs(280/100) & Loss 28.10317039489746
# Epochs(281/100) & Loss 28.009531021118164
# Epochs(282/100) & Loss 27.916568756103516
# Epochs(283/100) & Loss 27.82430648803711
# Epochs(284/100) & Loss 27.73276138305664
# Epochs(285/100) & Loss 27.641895294189453
# Epochs(286/100) & Loss 27.551692962646484
# Epochs(287/100) & Loss 27.462146759033203
# Epochs(288/100) & Loss 27.37325668334961
# Epochs(289/100) & Loss 27.28508949279785
# Epochs(290/100) & Loss 27.197444915771484
# Epochs(291/100) & Loss 27.110523223876953
# Epochs(292/100) & Loss 27.02423095703125
# Epochs(293/100) & Loss 26.93853187561035
# Epochs(294/100) & Loss 26.853519439697266
# Epochs(295/100) & Loss 26.76906967163086
# Epochs(296/100) & Loss 26.685190200805664
# Epochs(297/100) & Loss 26.60194969177246
# Epochs(298/100) & Loss 26.519241333007812
# Epochs(299/100) & Loss 26.43716812133789
# Epochs(300/100) & Loss 26.355682373046875
# Epochs(301/100) & Loss 26.27472496032715
# Epochs(302/100) & Loss 26.1943359375
# Epochs(303/100) & Loss 26.11458969116211
# Epochs(304/100) & Loss 26.03529930114746
# Epochs(305/100) & Loss 25.95656394958496
# Epochs(306/100) & Loss 25.87837791442871
# Epochs(307/100) & Loss 25.80076026916504
# Epochs(308/100) & Loss 25.723628997802734
# Epochs(309/100) & Loss 25.647098541259766
# Epochs(310/100) & Loss 25.570964813232422
# Epochs(311/100) & Loss 25.495399475097656
# Epochs(312/100) & Loss 25.42037582397461
# Epochs(313/100) & Loss 25.345775604248047
# Epochs(314/100) & Loss 25.271724700927734
# Epochs(315/100) & Loss 25.198108673095703
# Epochs(316/100) & Loss 25.125032424926758
# Epochs(317/100) & Loss 25.05238151550293
# Epochs(318/100) & Loss 24.98023223876953
# Epochs(319/100) & Loss 24.908601760864258
# Epochs(320/100) & Loss 24.83736228942871
# Epochs(321/100) & Loss 24.766590118408203
# Epochs(322/100) & Loss 24.696321487426758
# Epochs(323/100) & Loss 24.626422882080078
# Epochs(324/100) & Loss 24.556991577148438
# Epochs(325/100) & Loss 24.488040924072266
# Epochs(326/100) & Loss 24.41947364807129
# Epochs(327/100) & Loss 24.35138511657715
# Epochs(328/100) & Loss 24.283653259277344
# Epochs(329/100) & Loss 24.216405868530273
# Epochs(330/100) & Loss 24.14950942993164
# Epochs(331/100) & Loss 24.083065032958984
# Epochs(332/100) & Loss 24.017053604125977
# Epochs(333/100) & Loss 23.951370239257812
# Epochs(334/100) & Loss 23.886125564575195
# Epochs(335/100) & Loss 23.821243286132812
# Epochs(336/100) & Loss 23.75687026977539
# Epochs(337/100) & Loss 23.692752838134766
# Epochs(338/100) & Loss 23.629047393798828
# Epochs(339/100) & Loss 23.565696716308594
# Epochs(340/100) & Loss 23.50277328491211
# Epochs(341/100) & Loss 23.4401798248291
# Epochs(342/100) & Loss 23.37796974182129
# Epochs(343/100) & Loss 23.316164016723633
# Epochs(344/100) & Loss 23.25462532043457
# Epochs(345/100) & Loss 23.19353675842285
# Epochs(346/100) & Loss 23.1326904296875
# Epochs(347/100) & Loss 23.07228660583496
# Epochs(348/100) & Loss 23.012155532836914
# Epochs(349/100) & Loss 22.952356338500977
# Epochs(350/100) & Loss 22.892969131469727
# Epochs(351/100) & Loss 22.833866119384766
# Epochs(352/100) & Loss 22.775060653686523
# Epochs(353/100) & Loss 22.716642379760742
# Epochs(354/100) & Loss 22.658550262451172
# Epochs(355/100) & Loss 22.600732803344727
# Epochs(356/100) & Loss 22.543277740478516
# Epochs(357/100) & Loss 22.48609161376953
# Epochs(358/100) & Loss 22.42923355102539
# Epochs(359/100) & Loss 22.372692108154297
# Epochs(360/100) & Loss 22.31641387939453
# Epochs(361/100) & Loss 22.260440826416016
# Epochs(362/100) & Loss 22.204814910888672
# Epochs(363/100) & Loss 22.149452209472656
# Epochs(364/100) & Loss 22.09436798095703
# Epochs(365/100) & Loss 22.039623260498047
# Epochs(366/100) & Loss 21.985124588012695
# Epochs(367/100) & Loss 21.930871963500977
# Epochs(368/100) & Loss 21.876956939697266
# Epochs(369/100) & Loss 21.823314666748047
# Epochs(370/100) & Loss 21.769916534423828
# Epochs(371/100) & Loss 21.716848373413086
# Epochs(372/100) & Loss 21.663969039916992
# Epochs(373/100) & Loss 21.61140251159668
# Epochs(374/100) & Loss 21.559059143066406
# Epochs(375/100) & Loss 21.507055282592773
# Epochs(376/100) & Loss 21.455249786376953
# Epochs(377/100) & Loss 21.40371322631836
# Epochs(378/100) & Loss 21.352418899536133
# Epochs(379/100) & Loss 21.301361083984375
# Epochs(380/100) & Loss 21.250574111938477
# Epochs(381/100) & Loss 21.200082778930664
# Epochs(382/100) & Loss 21.149738311767578
# Epochs(383/100) & Loss 21.0997314453125
# Epochs(384/100) & Loss 21.049894332885742
# Epochs(385/100) & Loss 21.000301361083984
# Epochs(386/100) & Loss 20.950942993164062
# Epochs(387/100) & Loss 20.90186309814453
# Epochs(388/100) & Loss 20.852949142456055
# Epochs(389/100) & Loss 20.804304122924805
# Epochs(390/100) & Loss 20.75589370727539
# Epochs(391/100) & Loss 20.707704544067383
# Epochs(392/100) & Loss 20.659679412841797
# Epochs(393/100) & Loss 20.611957550048828
# Epochs(394/100) & Loss 20.564403533935547
# Epochs(395/100) & Loss 20.517086029052734
# Epochs(396/100) & Loss 20.469942092895508
# Epochs(397/100) & Loss 20.423046112060547
# Epochs(398/100) & Loss 20.37636375427246
# Epochs(399/100) & Loss 20.329849243164062

# %%
preds = model(inputs)
loss = MSE(target, preds)
print(loss)
# Out:
# tensor(20.2836, grad_fn=<DivBackward0>)

# %%
from math import sqrt
sqrt(loss)
# Out:
# 4.503729016935122

# %%
preds
# Out:
# tensor([[ 57.2541,  70.1743],
#         [ 77.9259,  99.1314],
#         [128.2841, 136.6749],
#         [ 21.9018,  36.0246],
#         [ 93.8439, 117.0515]], grad_fn=<AddBackward0>)

# %%
target
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %% [markdown]
# # Linear Regression using PyTorch built-ins

# %%
import torch.nn as nn

# %%
# Input (temp, rainfall, humidity)
inputs = np.array([[73, 67, 43], 
                   [91, 88, 64], 
                   [87, 134, 58], 
                   [102, 43, 37], 
                   [69, 96, 70], 
                   [74, 66, 43], 
                   [91, 87, 65], 
                   [88, 134, 59], 
                   [101, 44, 37], 
                   [68, 96, 71], 
                   [73, 66, 44], 
                   [92, 87, 64], 
                   [87, 135, 57], 
                   [103, 43, 36], 
                   [68, 97, 70]], 
                  dtype='float32')

# %%
inputs.shape
# Out:
# (15, 3)

# %%
# Targets (apples, oranges)
targets = np.array([[56, 70], 
                    [81, 101], 
                    [119, 133], 
                    [22, 37], 
                    [103, 119],
                    [57, 69], 
                    [80, 102], 
                    [118, 132], 
                    [21, 38], 
                    [104, 118], 
                    [57, 69], 
                    [82, 100], 
                    [118, 134], 
                    [20, 38], 
                    [102, 120]], 
                   dtype='float32')

# %%
inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)

# %%
print(inputs.dtype)
print(targets.dtype)
# Out:
# torch.float32
# torch.float32

# %%
# Dataset & DataLoader
from torch.utils.data import TensorDataset

# %%
#define dataset
train_ds = TensorDataset(inputs, targets)

# %%
type(train_ds)
# Out:
# torch.utils.data.dataset.TensorDataset

# %%
train_ds[0:3]
# Out:
# (tensor([[ 73.,  67.,  43.],
#          [ 91.,  88.,  64.],
#          [ 87., 134.,  58.]]), tensor([[ 56.,  70.],
#          [ 81., 101.],
#          [119., 133.]]))

# %%
from torch.utils.data import DataLoader

# %%
batch_size = 5
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

# %%
type(train_dl)
# Out:
# torch.utils.data.dataloader.DataLoader

# %%
for xb, yb in train_dl:
  print(xb)
  print(yb)
  break
# Out:
# tensor([[ 69.,  96.,  70.],
#         [ 68.,  97.,  70.],
#         [ 73.,  66.,  44.],
#         [ 68.,  96.,  71.],
#         [103.,  43.,  36.]])
# tensor([[103., 119.],
#         [102., 120.],
#         [ 57.,  69.],
#         [104., 118.],
#         [ 20.,  38.]])

# %%
#define model
model = nn.Linear(3,2)
print(model.weight)
print(model.bias)
# Out:
# Parameter containing:
# tensor([[ 0.0333,  0.3485, -0.1712],
#         [-0.2529,  0.2025,  0.1221]], requires_grad=True)
# Parameter containing:
# tensor([-0.4201,  0.1001], requires_grad=True)

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.0333,  0.3485, -0.1712],
#          [-0.2529,  0.2025,  0.1221]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.4201,  0.1001], requires_grad=True)]

# %%
preds = model(inputs)
preds
# Out:
# tensor([[ 1.8005e+01,  4.5854e-01],
#         [ 2.2329e+01,  2.7241e+00],
#         [ 3.9256e+01,  1.2319e+01],
#         [ 1.1633e+01, -1.2470e+01],
#         [ 2.3357e+01,  1.0642e+01],
#         [ 1.7689e+01,  3.0818e-03],
#         [ 2.1810e+01,  2.6437e+00],
#         [ 3.9118e+01,  1.2189e+01],
#         [ 1.1948e+01, -1.2014e+01],
#         [ 2.3153e+01,  1.1017e+01],
#         [ 1.7485e+01,  3.7815e-01],
#         [ 2.2014e+01,  2.2686e+00],
#         [ 3.9776e+01,  1.2400e+01],
#         [ 1.1837e+01, -1.2845e+01],
#         [ 2.3673e+01,  1.1097e+01]], grad_fn=<AddmmBackward0>)

# %%
targets
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.],
#         [ 57.,  69.],
#         [ 80., 102.],
#         [118., 132.],
#         [ 21.,  38.],
#         [104., 118.],
#         [ 57.,  69.],
#         [ 82., 100.],
#         [118., 134.],
#         [ 20.,  38.],
#         [102., 120.]])

# %%
#loss function
import torch.nn.functional as F

# %%
loss_fn  = F.mse_loss

# %%
# ??nn.Linear

# %%
loss = loss_fn(model(inputs), targets)
print(loss)
# Out:
# tensor(6087.3535, grad_fn=<MseLossBackward0>)

# %%
#optimizers
opt = torch.optim.SGD(model.parameters(), lr= 1e-5)

# %%
def fit(num_epochs, model, loss_fn, opt):
  for epoch in range(1,num_epochs+1):
    for xb, yb in train_dl:
      pred = model(xb)
      loss = loss_fn(pred, yb)
      loss.backward()
      opt.step()
      opt.zero_grad()
    
    if(epoch) % 10 ==0:
      print(f'Epoch [{epoch}/{num_epochs}], Loss {loss.item()}')

# %%
fit(100, model, loss_fn, opt)
# Out:
# Epoch [10/100], Loss 146.14207458496094
# Epoch [20/100], Loss 333.1202697753906
# Epoch [30/100], Loss 67.80695343017578
# Epoch [40/100], Loss 79.31674194335938
# Epoch [50/100], Loss 33.19841766357422
# Epoch [60/100], Loss 76.24372100830078
# Epoch [70/100], Loss 21.04210090637207
# Epoch [80/100], Loss 44.46441650390625
# Epoch [90/100], Loss 36.90877151489258
# Epoch [100/100], Loss 27.580245971679688

# %%
preds = model(inputs)
preds
# Out:
# tensor([[ 58.1973,  71.2937],
#         [ 79.2595,  98.5598],
#         [123.1435, 136.3076],
#         [ 27.5918,  42.2535],
#         [ 92.9538, 112.4204],
#         [ 57.0212,  70.2557],
#         [ 78.5153,  98.2359],
#         [123.1519, 136.7040],
#         [ 28.7678,  43.2916],
#         [ 93.3857, 113.1346],
#         [ 57.4532,  70.9698],
#         [ 78.0834,  97.5217],
#         [123.8876, 136.6315],
#         [ 27.1598,  41.5394],
#         [ 94.1298, 113.4585]], grad_fn=<AddmmBackward0>)

# %%
targets
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.],
#         [ 57.,  69.],
#         [ 80., 102.],
#         [118., 132.],
#         [ 21.,  38.],
#         [104., 118.],
#         [ 57.,  69.],
#         [ 82., 100.],
#         [118., 134.],
#         [ 20.,  38.],
#         [102., 120.]])

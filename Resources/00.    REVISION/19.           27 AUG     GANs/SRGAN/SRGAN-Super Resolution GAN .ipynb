# %%
# %cd /content/drive/MyDrive/005_BOKTIAR_AHMED_BAPPY/My_classes/FSDS-Bootcamp/GANs/SRGAN
# Out:
# /content/drive/MyDrive/005_BOKTIAR_AHMED_BAPPY/My_classes/FSDS-Bootcamp/GANs/SRGAN

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/005_BOKTIAR_AHMED_BAPPY/My_classes/FSDS-Bootcamp/GANs/SRGAN'

# %%
# !git clone https://github.com/entbappy/SRGAN-Super-Resolution-GAN.git
# Out:
# Cloning into 'SRGAN_CustomDataset'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 73 (delta 22), reused 47 (delta 6), pack-reused 0
# Unpacking objects: 100% (73/73), 15.93 MiB | 8.25 MiB/s, done.

# %%
# %cd SRGAN_CustomDataset
# Out:
# /content/drive/MyDrive/005_BOKTIAR_AHMED_BAPPY/My_classes/FSDS-Bootcamp/GANs/SRGAN/SRGAN_CustomDataset

# %%
# %ls
# Out:
# custom_dataset/  losses.py    mode.py             README.md       vgg19.py
# Data/            main.py      ops.py              result/
# dataset.py       main.py.bak  pretrained_models/  srgan_model.py
# environment.yml  model/       __pycache__/        test_data/

# %%
# !pip install --upgrade scikit-image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 81.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/005_BOKTIAR_AHMED_BAPPY/My_classes/FSDS-Bootcamp/GANs/SRGAN/SRGAN_CustomDataset'

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/005_BOKTIAR_AHMED_BAPPY/My_classes/FSDS-Bootcamp/GANs/SRGAN/SRGAN_CustomDataset'

# %%
#change inside mode.py line no 178
from skimage.metrics import peak_signal_noise_ratio

# %%
#train
# !python main.py --LR_path Data/train_LR --GT_path Data/train_HR
# Out:
# 2
# 0.19919468462467194
# ...
# 4
# 0.1354437917470932
# ...
# 6
# 0.11162371188402176
# ...
# 8
# 0.08686375617980957
# ...
# 10
# 0.07976096123456955
# ...
# 12
# 0.05297808721661568
# ...
# 14
# 0.08062830567359924
# ...
# 16
# 0.08789902925491333
# ...
# 18
# 0.06040718033909798
# ...
# 20
# 0.1038389652967453
# ...
# 22
# 0.03812874108552933
# ...
# 24
# 0.06527100503444672
# ...
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/005_BOKTIAR_AHMED_BAPPY/My_classes/FSDS-Bootcamp/GANs/SRGAN/SRGAN_CustomDataset/main.py", line 32, in <module>
#     train(args)
#   File "/content/drive/MyDrive/005_BOKTIAR_AHMED_BAPPY/My_classes/FSDS-Bootcamp/GANs/SRGAN/SRGAN_CustomDataset/mode.py", line 44, in train
#     gt = tr_data['GT'].to(device)
# KeyboardInterrupt
# ^C

# %%
#test
# !python main.py --mode test_only --LR_path test_data/cars --generator_path pretrained_models/SRGAN.pt

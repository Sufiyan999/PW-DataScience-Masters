# %% [markdown]
# <h>Ans_1

# %% [markdown]
# read_csv(): This function is used to read data from a CSV file and create a Pandas DataFrame.

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# head(): This function returns the first n rows of a DataFrame. The default value of n is 5

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# describe(): This function returns statistical information about the DataFrame, such as count, mean, standard deviation, and quartiles

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# groupby(): This function is used to group a DataFrame by one or more columns and perform aggregate functions on the groups.

# %%
grouped = df.groupby('Sex')["Fare"]
print(grouped.mean())
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %% [markdown]
# plot(): This function is used to create a variety of plots, such as line plots, scatter plots, and histograms, from a DataFrame

# %%
import matplotlib.pyplot as plt

df.plot(kind='scatter', x='Age', y='Fare')
plt.show()

# %% [markdown]
# <h>ans_2

# %%
import pandas as pd


def reindex_df(df):
    df.index = pd.RangeIndex(start=1, stop=len(df)*2, step=2)
    return df

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
reindexed_df = reindex_df(df)
reindexed_df
# Out:
#    A  B  C
# 1  1  4  7
# 3  2  5  8
# 5  3  6  9

# %% [markdown]
# <h>ans_3

# %%
import pandas as pd

def sum_first_three(df):
    sum = 0
    value_series = df['Values']
    for i in range(3):
        sum += value_series[i]
    print("Sum of first three values:", sum)

# %%
df = pd.DataFrame({'Values': [10, 20, 30, 40, 50]} ,index=['a' ,'b','c' ,'d' , 'e'])
df
# Out:
#    Values
# a      10
# b      20
# c      30
# d      40
# e      50

# %%
sum_first_three(df)
# Out:
# Sum of first three values: 60

# %% [markdown]
# <h>ans_4

# %%
import pandas as pd
def add_word_count(df):
    df['Word_Count'] = df['Text'].apply(lambda x: len(str(x).split()))

# %%
df = pd.DataFrame({'Text': ['This is a sentence', 'Another sentence', 'A third sentence' ,"we can continue it as per we want"]})

add_word_count(df)

print(df)
# Out:
#                                 Text  Word_Count
# 0                 This is a sentence           4
# 1                   Another sentence           2
# 2                   A third sentence           3
# 3  we can continue it as per we want           8

# %% [markdown]
# <h>ans_5

# %% [markdown]
# In Pandas, DataFrame.size() and DataFrame.shape() are both methods that can be used to get information about the dimensions of a DataFrame, but they return different information.
#
# The DataFrame.size() method returns the total number of elements in the DataFrame. For example, if a DataFrame has 3 rows and 4 columns, DataFrame.size() would return 12, which is the total number of elements in the DataFrame.
#
# On the other hand, the DataFrame.shape() method returns a tuple representing the dimensions of the DataFrame. The tuple contains two values: the number of rows and the number of columns, respectively. For example, if a DataFrame has 3 rows and 4 columns, DataFrame.shape() would return the tuple (3, 4).

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
print(df.size)  
print(df.shape)
# Out:
# 9
# (3, 3)

# %% [markdown]
# <h>ans_6

# %% [markdown]
# To read an Excel file in Pandas, we use the read_excel() function, which is a part of the Pandas library. The read_excel() function reads the data from the Excel file and creates a DataFrame.

# %%
import pandas as pd

# Read the Excel file into a DataFrame
df = pd.read_excel('data.xlsx')

# Display the first 5 rows of the DataFrame
print(df.head())

# %%
# Read the second sheet of the Excel file into a DataFrame
df = pd.read_excel('data.xlsx', sheet_name='Sheet2')

# %% [markdown]
# <h>ans_7

# %%
import random
import string

domains = ['gmail.com', 'yahoo.com', 'hotmail.com', 'outlook.com']

def generate_email():
    username = ''.join(random.choices(string.ascii_lowercase , k=random.randint(5, 10)))
    domain = random.choice(domains)
    return f"{username}@{domain}"

emails = [generate_email() for _ in range(25)]

print(emails)
# Out:
# ['vzduqi@gmail.com', 'efnuxoxqe@gmail.com', 'vtqnh@yahoo.com', 'lzncnhedtz@yahoo.com', 'rskgrfetuy@outlook.com', 'jrytqd@yahoo.com', 'qozjtv@outlook.com', 'mmocseayi@yahoo.com', 'edmwrptd@outlook.com', 'pkefxd@gmail.com', 'rchmecf@hotmail.com', 'wnfmwnq@outlook.com', 'cflmp@gmail.com', 'yrijuckc@hotmail.com', 'vxtoyucnj@outlook.com', 'gwwyyms@gmail.com', 'ztupe@gmail.com', 'gnyttrvxa@yahoo.com', 'wwztcwfqi@outlook.com', 'pbmhgxbzds@outlook.com', 'fybrvflub@outlook.com', 'ygapszzlz@outlook.com', 'rxcsx@yahoo.com', 'ptvnbi@yahoo.com', 'ecxtl@gmail.com']

# %%
emails = ['john.doe@example.com',
'jane.smith@yahoo.com',
'mike.williams@gmail.com',
'sara.jones@hotmail.com',
'jason.nguyen@outlook.com',
'katie.brown@icloud.com',
'steve.miller@aol.com',
'emily.taylor@live.com',
'tom.harris@msn.com',
'lauren.carter@me.com',
'jacob.robinson@protonmail.com',
'anna.wilson@zoho.com',
'chris.wright@gmx.com',
'lisa.jackson@yandex.com',
'kevin.moore@mail.com',
'megan.lewis@inbox.com',
'jared.thomas@fastmail.com',
'julia.nelson@hushmail.com',
'andrew.cook@tutanota.com',
'amanda.white@mailbox.org',
'brian.clark@runbox.com',
'olivia.johnson@startmail.com',
'paul.garcia@countermail.com',
'erin.walker@mailfence.com',
'samuel.taylor@cock.li']

# %%
import pandas as pd

# Create a sample DataFrame with email addresses
data = {'Email': emails}
df = pd.DataFrame(data)

# Define a function to extract the username from each email address
def extract_username(email):
    return email.split('@')[0]

# Apply the function to the 'Email' column and store the result in a new 'Username' column
df['Username'] = df['Email'].apply(extract_username)

# Display the DataFrame with the new 'Username' column
print(df)
# Out:
#                             Email        Username
# 0            john.doe@example.com        john.doe
# 1            jane.smith@yahoo.com      jane.smith
# 2         mike.williams@gmail.com   mike.williams
# 3          sara.jones@hotmail.com      sara.jones
# 4        jason.nguyen@outlook.com    jason.nguyen
# 5          katie.brown@icloud.com     katie.brown
# 6            steve.miller@aol.com    steve.miller
# 7           emily.taylor@live.com    emily.taylor
# 8              tom.harris@msn.com      tom.harris
# 9            lauren.carter@me.com   lauren.carter
# 10  jacob.robinson@protonmail.com  jacob.robinson
# 11           anna.wilson@zoho.com     anna.wilson
# 12           chris.wright@gmx.com    chris.wright
# 13        lisa.jackson@yandex.com    lisa.jackson
# 14           kevin.moore@mail.com     kevin.moore
# 15          megan.lewis@inbox.com     megan.lewis
# 16      jared.thomas@fastmail.com    jared.thomas
# 17      julia.nelson@hushmail.com    julia.nelson
# ...

# %% [markdown]
# <h>ans_8

# %%
import pandas as pd

def select_rows(df):
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]
    return pd.DataFrame(selected_rows)

# %%
df = pd.DataFrame({'A': [3, 8, 6, 2, 9], 'B': [5, 2, 9, 3, 1], 'C': [1, 7, 4, 5, 2]})
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
select_rows(df)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# <h>ans_9

# %%
import pandas as pd

def calculate_stats(df):
    mean = df['Values'].mean()
    median = df['Values'].median()
    std_daviation = df['Values'].std()
    
    print("Mean: ", mean)
    print("Median: ", median)
    print("Standard Deviation: ", std_daviation)

# %%
import numpy as np
value = np.random.randint(3,40,size=10)
value
# Out:
# array([19,  7, 14, 37, 21, 27, 14,  6, 29, 17])

# %%
df = pd.DataFrame({'Values': value})
calculate_stats(df)
# Out:
# Mean:  19.1
# Median:  18.0
# Standard Deviation:  9.768998583955948

# %% [markdown]
# <h>ans_10

# %%
import pandas as pd

def calculate_moving_average(df):
    df['MovingAverage'] = df['Sales'].rolling(window=7,min_periods=1).mean()
    return df

# %%
import pandas as pd
import numpy as np

# create a datetime range for 30 days starting from today
dates = pd.date_range(start=pd.Timestamp.now().date(), periods=30)

sales = np.random.randint(100, 1000, size=30)

# %%
df = pd.DataFrame({'Date': dates, 'Sales': sales})

# calculate the moving average for the past 7 days for each row
df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()

df
# Out:
#          Date  Sales  MovingAverage
# 0  2023-05-07    121     121.000000
# 1  2023-05-08    434     277.500000
# 2  2023-05-09    916     490.333333
# 3  2023-05-10    152     405.750000
# 4  2023-05-11    734     471.400000
# 5  2023-05-12    201     426.333333
# 6  2023-05-13    447     429.285714
# 7  2023-05-14    395     468.428571
# 8  2023-05-15    255     442.857143
# 9  2023-05-16    973     451.000000
# 10 2023-05-17    527     504.571429
# 11 2023-05-18    130     418.285714
# 12 2023-05-19    724     493.000000
# 13 2023-05-20    320     474.857143
# 14 2023-05-21    148     439.571429
# 15 2023-05-22    939     537.285714
# 16 2023-05-23    254     434.571429
# 17 2023-05-24    454     424.142857
# 18 2023-05-25    421     465.714286
# 19 2023-05-26    384     417.142857
# 20 2023-05-27    790     484.285714
# 21 2023-05-28    625     552.428571
# 22 2023-05-29    552     497.142857
# 23 2023-05-30    389     516.428571
# 24 2023-05-31    238     485.571429
# ...

# %% [markdown]
# <h>ans_11

# %%
import pandas as pd

def add_weekday_column(df):
    
    df['Date'] = pd.to_datetime(df['Date'])
 
    df['Weekday'] = df['Date'].dt.strftime('%A')
    return df

# %%
df = pd.DataFrame({'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']})
df_with_weekday = add_weekday_column(df)
print(df_with_weekday)
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# <h>ans_12

# %%
import pandas as pd

df = pd.DataFrame({
    'Date': pd.date_range(start='2023-01-01', end='2023-02-28', freq='D'),
    'Value': [i for i in range(1, 60)]
})

def select_january_dates(df):
    start_date = pd.Timestamp('2023-01-01')
    end_date = pd.Timestamp('2023-01-31')
    return df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

select_january_dates(df)
# Out:
#          Date  Value
# 0  2023-01-01      1
# 1  2023-01-02      2
# 2  2023-01-03      3
# 3  2023-01-04      4
# 4  2023-01-05      5
# 5  2023-01-06      6
# 6  2023-01-07      7
# 7  2023-01-08      8
# 8  2023-01-09      9
# 9  2023-01-10     10
# 10 2023-01-11     11
# 11 2023-01-12     12
# 12 2023-01-13     13
# 13 2023-01-14     14
# 14 2023-01-15     15
# 15 2023-01-16     16
# 16 2023-01-17     17
# 17 2023-01-18     18
# 18 2023-01-19     19
# 19 2023-01-20     20
# 20 2023-01-21     21
# 21 2023-01-22     22
# 22 2023-01-23     23
# 23 2023-01-24     24
# 24 2023-01-25     25
# 25 2023-01-26     26
# 26 2023-01-27     27
# 27 2023-01-28     28
# 28 2023-01-29     29
# 29 2023-01-30     30
# 30 2023-01-31     31

# %%
import random
import datetime

start_date = pd.Timestamp('2023-01-01')
end_date = pd.Timestamp('2023-03-28')
days_diff = (end_date - start_date).days

random_dates = []
for i in range(25):
    random_day = start_date + datetime.timedelta(days=random.randint(0, days_diff))
    random_dates.append(random_day)
    
print(random_dates)
# Out:
# [Timestamp('2023-02-01 00:00:00'), Timestamp('2023-01-21 00:00:00'), Timestamp('2023-03-10 00:00:00'), Timestamp('2023-01-31 00:00:00'), Timestamp('2023-01-31 00:00:00'), Timestamp('2023-01-03 00:00:00'), Timestamp('2023-03-14 00:00:00'), Timestamp('2023-01-09 00:00:00'), Timestamp('2023-03-01 00:00:00'), Timestamp('2023-01-01 00:00:00'), Timestamp('2023-01-23 00:00:00'), Timestamp('2023-03-13 00:00:00'), Timestamp('2023-02-14 00:00:00'), Timestamp('2023-02-09 00:00:00'), Timestamp('2023-03-08 00:00:00'), Timestamp('2023-02-14 00:00:00'), Timestamp('2023-02-24 00:00:00'), Timestamp('2023-03-02 00:00:00'), Timestamp('2023-03-03 00:00:00'), Timestamp('2023-03-12 00:00:00'), Timestamp('2023-03-26 00:00:00'), Timestamp('2023-03-12 00:00:00'), Timestamp('2023-01-17 00:00:00'), Timestamp('2023-03-22 00:00:00'), Timestamp('2023-02-19 00:00:00')]

# %%
df = pd.DataFrame({
    'Date': random_dates,
    'Value': [i for i in range(25)]
})
select_january_dates(df)
# Out:
#          Date  Value
# 1  2023-01-21      1
# 3  2023-01-31      3
# 4  2023-01-31      4
# 5  2023-01-03      5
# 7  2023-01-09      7
# 9  2023-01-01      9
# 10 2023-01-23     10
# 22 2023-01-17     22

# %% [markdown]
# <h>ans_13

# %% [markdown]
# To use the basic functions of pandas, you need to import the pandas library.

# %%
import pandas as pd

# %% [markdown]
# Pandas is built on top of the NumPy library, so NumPy is a package that Pandas depends on. Additionally, some Pandas functions rely on other Python libraries such as Matplotlib, SciPy, and Scikit-learn.
